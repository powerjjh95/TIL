# %%
# numpy 배열 생성
# numpy 활용을 위해서 numpy 패키지를 import를 해야한다.
import numpy as np

# a1 = np.array([1, 2, 3])
# print(a1)
# print('array1 type : ', type(a1))
# 배열의 크기
# print('array1 shape : ', a1.shape)

# 이차원 배열
# a2 = np.array([[1,2,3],[4,5,6]])
# print(a2)
# print('array2 type : ', type(a2))
# # 배열의 크기
# print('array2 shape : ', a2.shape)

# # []의 개수에 따라 배열의 차원이 달라진다.
# a3 = np.array([[1,2,3]])
# print(a3)
# print('array3 type : ', type(a3))
# # 배열의 크기
# print('array3 shape : ', a3.shape)

# #각 배열의 차원 확인
# print('array1 dim : ', a1.ndim)
# print('array2 dim : ', a2.ndim)
# print('array3 dim : ', a3.ndim)

# 특정크기와 차원을 가진 배열을 연속되거나 일정한 규칙을 가진 숫자로 생성해야 할 필요가
# 있다.
# 이때, np.arrange(x) 함수를 활용하면 0부터(x-1)까지의 값을 순차적 배열의 데이터 값으로 생성
# a = np.arange(20)

# np.arange(x, y, z)로 함수를 호출하면 x값부터 (y-1)값 까지 z값 만큼 증가하는 배열 생성이 가능하다.
# a = np.arange(1, 20,3)
# print(a)

# numpy 배열 초기화
# zeros, ones 함수 이용
# zero_a = np.zeros((2, 5)) # 2차원 배열을 0으로 초기화
# print(zero_a)
# one_a = np.ones((3,4)) # 2차원 배열을 1로 초기화
# print(one_a)
# # 이미 생성된 배열의 구조를 동일한 구조를 유지한 상태에서 0으로 채워진 배열로 초기화 하여 생성하는 방법
# zero_b = np.zeros_like(one_a)
# print(zero_b)
# # 이미 생성된 배열의 구조를 동일한 구조를 유지한 상태에서 1으로 채워진 배열로 초기화 하여 생성하는 방법
# one_b = np.ones_like(zero_a)
# print(one_b)

# #모든 값이 특정 상수인 배열을 생성, 혹은 임의의(Random)값으로 채워진 배열을 생성하는 방법
# full_a = np.full((4,3), 10)
# print(full_a)

# random_a = np.random.random((3, 4))
# print(random_a)

# 대각행렬 생성
# eye_a = np.eye(4)
# print(eye_a)

# # numpy 배열 크기 변형
# # 배열의 차원과 크기를 변경하는 reshape함수 사용
# array1 = np.arange(12)
# print('array1 : \n', array1)

# array2 = array1.reshape(3, 4)
# print('array2 : \n', array2)

# array3 = array1.reshape(3, 4, order='F')  # 배열의 차원도 변환시키면서 값을 열부터 채워 넣는다.
# print('array3 : \n', array3)

# array1 = np.arange(10)
# print('array1 : \n', array1)
# array2 = array1.reshape(3, 4)
# print('array1 : \n', array2)

# reshape 함수를 사용할 때 인자로 -1을 입력하는 경우가 일반적이다.
# -1을 인자로 사용하면 원래 배열과 호환되는 크기로 자동으로 변환해 준다.
# array1 = np.arange(10)
# print('array1 : \n', array1)
# array2 = array1.reshape(-1, 5)
# print('array2 : \n', array2)
# array1 = np.arange(12)
# array2 = array1.reshape(2, 3, 2, order='F')
# print('array2 dim : ', array2.ndim)
# print('array2 shape : ', array2.shape)
# print('\n')
# array3 = array2.flatten()   # 다시 3차원에서 원래 1차원으로 변환
# print(array3)
# print('array3 dim : ', array3.ndim)
# print('array3 shape : ', array3.shape)

# numpy 배열 데이터 추출하기
# 인덱싱 : 한 개의 데이터만 추출하려면 배열의 요소에 해당하는 인덱스 값을 []안 입력하면 된다.
# array1 = np.arange(1, 10)
# print('array1 : ', array1)

# value1 = array1[2]
# value2 = array1[-2] # 인덱스 값이 -인 경우는 뒤에서부터 데이터를 순서대로 추출한다.
# print('value1 : ', value1)
# print('value2 : ', value2)

# #다차원 배열에서 추출하기
# array1 = np.arange(1, 10)
# array2 = array1.reshape(3, 3)
# print('array2 : \n', array2)

# value1 = array2[0, 0]
# value2 = array2[-1, -1]
# value3 = array2[-1, -2]
# print('value1 : ', value1)
# print('value2 : ', value2)
# print('value3 : ', value3)
# print('value1 type : ', type(value1))

# 슬라이싱 추출 기법으로서 [x : y] 기호를 이용하면 배열에서 연속한 데이터를 추출
# 할 수가 있다. x는 시작 인덱스, y는 종료 인덱스
# array1 = np.arange(1, 10)
# print('array1 : ', array1)
# array2 = array1[0:3]
# print('array2 : ', array2)
# print('array2 type', type(array2))

# array3 = array1[:5] #앞 인덱스를 생략을 하면 시작 인덱스를 0으로 간주
# print('array3 : ', array3)

# array4 = array1[3:] #뒤 인덱스를 생략을 하면 마지막 인덱스로 간주
# print('array4 : ', array4)

# 다차원 배열의 슬라이싱
# array1 = np.arange(1, 10)
# array2 = array1.reshape(3, 3)
# print('array2 : \n ', array2)

# print('array[0:2, 0:3]\n', array2[0:2, 0:3])
# print('array[1:3, 0:3]\n', array2[1:3, 0:3])
